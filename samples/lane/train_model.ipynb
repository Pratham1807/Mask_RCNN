# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install q keras==2.1.0
# Out:
# Collecting q
#   Downloading https://files.pythonhosted.org/packages/53/bc/51619d89e0bd855567e7652fa16d06f1ed36a85f108a7fe71f6629bf719d/q-2.6-py2.py3-none-any.whl
# Collecting keras==2.1.0
#   Downloading https://files.pythonhosted.org/packages/bf/c2/b0c2ece713e754d1692aa432ad682751cd1ad6abf7500a534558b1fbfbe7/Keras-2.1.0-py2.py3-none-any.whl (302kB)
#      |████████████████████████████████| 307kB 12.1MB/s
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.1.0) (1.12.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.1.0) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.1.0) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.1.0) (1.18.3)
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.1.0 which is incompatible.
# Installing collected packages: q, keras
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed keras-2.1.0 q-2.6

# %%
import os
import sys
import json
import datetime
import numpy as np
import skimage.draw

# Root directory of the project
ROOT_DIR = os.path.abspath("/content/drive/My Drive/Mask_RCNN-master")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn.config import Config
from mrcnn import model as modellib, utils

from samples.lane import lane

# Path to trained weights file
COCO_WEIGHTS_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Directory to save logs and model checkpoints, if not provided
# through the command line argument --logs
DEFAULT_LOGS_DIR = os.path.join(ROOT_DIR, "logs")
# Out:
# Using TensorFlow backend.

# %%
config = lane.LaneConfig()
LANE_DIR = os.path.join(ROOT_DIR, "datasets/lane")

# %%
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.8
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           lane
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
model = modellib.MaskRCNN(mode="training", config=config, model_dir=DEFAULT_LOGS_DIR)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:492: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:63: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3630: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3458: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1822: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1208: calling reduce_max_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1242: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/My Drive/Mask_RCNN-master/mrcnn/model.py:553: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Mask_RCNN-master/mrcnn/utils.py:202: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Mask_RCNN-master/mrcnn/model.py:600: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead

# %%
weights_path = COCO_WEIGHTS_PATH
# Download weights file
if not os.path.exists(weights_path):
    utils.download_trained_weights(weights_path)

# %%
print("Loading weights ", weights_path)
model.load_weights(weights_path, by_name=True, exclude=[
            "mrcnn_class_logits", "mrcnn_bbox_fc",
            "mrcnn_bbox", "mrcnn_mask"])
# Out:
# Loading weights  /content/drive/My Drive/Mask_RCNN-master/mask_rcnn_coco.h5
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:158: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:163: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:168: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:172: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:188: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
DATASET_DIR = os.path.join(ROOT_DIR,"datasets/lane")
lane.train(model,DATASET_DIR)
# Out:
# Training network heads
#
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /content/drive/My Drive/Mask_RCNN-master/logs/lane20200429T2149/mask_rcnn_lane_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:711: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:953: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:675: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:940: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:705: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:708: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:2039: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/30
#  99/100 [============================>.] - ETA: 0s - loss: 1.0187 - rpn_class_loss: 0.0157 - rpn_bbox_loss: 0.2297 - mrcnn_class_loss: 0.0240 - mrcnn_bbox_loss: 0.3772 - mrcnn_mask_loss: 0.3720
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:2197: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:791: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# 100/100 [==============================] - 120s 1s/step - loss: 1.0125 - rpn_class_loss: 0.0156 - rpn_bbox_loss: 0.2284 - mrcnn_class_loss: 0.0239 - mrcnn_bbox_loss: 0.3751 - mrcnn_mask_loss: 0.3696 - val_loss: 1.5859 - val_rpn_class_loss: 0.0114 - val_rpn_bbox_loss: 0.4947 - val_mrcnn_class_loss: 0.0073 - val_mrcnn_bbox_loss: 0.7526 - val_mrcnn_mask_loss: 0.3200
# Epoch 2/30
# 100/100 [==============================] - 53s 531ms/step - loss: 0.4688 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.1402 - mrcnn_class_loss: 0.0096 - mrcnn_bbox_loss: 0.1725 - mrcnn_mask_loss: 0.1416 - val_loss: 1.5431 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 0.5337 - val_mrcnn_class_loss: 0.0062 - val_mrcnn_bbox_loss: 0.7291 - val_mrcnn_mask_loss: 0.2672
# Epoch 3/30
# 100/100 [==============================] - 53s 534ms/step - loss: 0.2939 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0998 - mrcnn_class_loss: 0.0074 - mrcnn_bbox_loss: 0.0819 - mrcnn_mask_loss: 0.1019 - val_loss: 1.4955 - val_rpn_class_loss: 0.0047 - val_rpn_bbox_loss: 0.5921 - val_mrcnn_class_loss: 0.0057 - val_mrcnn_bbox_loss: 0.6660 - val_mrcnn_mask_loss: 0.2270
# Epoch 4/30
# 100/100 [==============================] - 54s 536ms/step - loss: 0.2364 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0817 - mrcnn_class_loss: 0.0071 - mrcnn_bbox_loss: 0.0617 - mrcnn_mask_loss: 0.0840 - val_loss: 1.6007 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.5938 - val_mrcnn_class_loss: 0.0054 - val_mrcnn_bbox_loss: 0.6045 - val_mrcnn_mask_loss: 0.3909
# Epoch 5/30
# 100/100 [==============================] - 54s 538ms/step - loss: 0.1837 - rpn_class_loss: 0.0017 - rpn_bbox_loss: 0.0608 - mrcnn_class_loss: 0.0052 - mrcnn_bbox_loss: 0.0514 - mrcnn_mask_loss: 0.0647 - val_loss: 1.6028 - val_rpn_class_loss: 0.0044 - val_rpn_bbox_loss: 0.6291 - val_mrcnn_class_loss: 0.0033 - val_mrcnn_bbox_loss: 0.5622 - val_mrcnn_mask_loss: 0.4038
# Epoch 6/30
# 100/100 [==============================] - 54s 535ms/step - loss: 0.1605 - rpn_class_loss: 0.0017 - rpn_bbox_loss: 0.0445 - mrcnn_class_loss: 0.0059 - mrcnn_bbox_loss: 0.0525 - mrcnn_mask_loss: 0.0560 - val_loss: 1.5024 - val_rpn_class_loss: 0.0042 - val_rpn_bbox_loss: 0.5908 - val_mrcnn_class_loss: 0.0051 - val_mrcnn_bbox_loss: 0.6046 - val_mrcnn_mask_loss: 0.2977
# Epoch 7/30
# 100/100 [==============================] - 54s 538ms/step - loss: 0.1197 - rpn_class_loss: 0.0015 - rpn_bbox_loss: 0.0258 - mrcnn_class_loss: 0.0048 - mrcnn_bbox_loss: 0.0345 - mrcnn_mask_loss: 0.0532 - val_loss: 1.5397 - val_rpn_class_loss: 0.0045 - val_rpn_bbox_loss: 0.6055 - val_mrcnn_class_loss: 0.0042 - val_mrcnn_bbox_loss: 0.6751 - val_mrcnn_mask_loss: 0.2503
# Epoch 8/30
# 100/100 [==============================] - 53s 532ms/step - loss: 0.1144 - rpn_class_loss: 0.0012 - rpn_bbox_loss: 0.0273 - mrcnn_class_loss: 0.0038 - mrcnn_bbox_loss: 0.0342 - mrcnn_mask_loss: 0.0479 - val_loss: 1.6531 - val_rpn_class_loss: 0.0058 - val_rpn_bbox_loss: 0.6571 - val_mrcnn_class_loss: 0.0035 - val_mrcnn_bbox_loss: 0.6884 - val_mrcnn_mask_loss: 0.2984
# Epoch 9/30
# 100/100 [==============================] - 53s 531ms/step - loss: 0.1035 - rpn_class_loss: 0.0013 - rpn_bbox_loss: 0.0278 - mrcnn_class_loss: 0.0042 - mrcnn_bbox_loss: 0.0255 - mrcnn_mask_loss: 0.0448 - val_loss: 1.4022 - val_rpn_class_loss: 0.0050 - val_rpn_bbox_loss: 0.6427 - val_mrcnn_class_loss: 0.0050 - val_mrcnn_bbox_loss: 0.5377 - val_mrcnn_mask_loss: 0.2118
# Epoch 10/30
# 100/100 [==============================] - 53s 534ms/step - loss: 0.0788 - rpn_class_loss: 0.0012 - rpn_bbox_loss: 0.0098 - mrcnn_class_loss: 0.0044 - mrcnn_bbox_loss: 0.0236 - mrcnn_mask_loss: 0.0399 - val_loss: 1.3660 - val_rpn_class_loss: 0.0029 - val_rpn_bbox_loss: 0.5949 - val_mrcnn_class_loss: 0.0102 - val_mrcnn_bbox_loss: 0.4887 - val_mrcnn_mask_loss: 0.2695
# Epoch 11/30
# 100/100 [==============================] - 53s 534ms/step - loss: 0.0832 - rpn_class_loss: 8.1322e-04 - rpn_bbox_loss: 0.0145 - mrcnn_class_loss: 0.0050 - mrcnn_bbox_loss: 0.0223 - mrcnn_mask_loss: 0.0406 - val_loss: 1.5341 - val_rpn_class_loss: 0.0039 - val_rpn_bbox_loss: 0.6139 - val_mrcnn_class_loss: 0.0060 - val_mrcnn_bbox_loss: 0.6077 - val_mrcnn_mask_loss: 0.3025
# Epoch 12/30
# 100/100 [==============================] - 53s 534ms/step - loss: 0.0631 - rpn_class_loss: 6.6371e-04 - rpn_bbox_loss: 0.0064 - mrcnn_class_loss: 0.0022 - mrcnn_bbox_loss: 0.0126 - mrcnn_mask_loss: 0.0412 - val_loss: 1.4937 - val_rpn_class_loss: 0.0032 - val_rpn_bbox_loss: 0.5639 - val_mrcnn_class_loss: 0.0046 - val_mrcnn_bbox_loss: 0.5953 - val_mrcnn_mask_loss: 0.3268
# Epoch 13/30
# 100/100 [==============================] - 54s 545ms/step - loss: 0.0599 - rpn_class_loss: 8.7272e-04 - rpn_bbox_loss: 0.0085 - mrcnn_class_loss: 0.0031 - mrcnn_bbox_loss: 0.0136 - mrcnn_mask_loss: 0.0339 - val_loss: 1.5024 - val_rpn_class_loss: 0.0033 - val_rpn_bbox_loss: 0.5989 - val_mrcnn_class_loss: 0.0054 - val_mrcnn_bbox_loss: 0.6208 - val_mrcnn_mask_loss: 0.2741
# Epoch 14/30
# 100/100 [==============================] - 54s 535ms/step - loss: 0.0734 - rpn_class_loss: 5.5109e-04 - rpn_bbox_loss: 0.0107 - mrcnn_class_loss: 0.0031 - mrcnn_bbox_loss: 0.0196 - mrcnn_mask_loss: 0.0395 - val_loss: 1.4678 - val_rpn_class_loss: 0.0037 - val_rpn_bbox_loss: 0.5964 - val_mrcnn_class_loss: 0.0046 - val_mrcnn_bbox_loss: 0.5448 - val_mrcnn_mask_loss: 0.3183
# Epoch 15/30
# 100/100 [==============================] - 54s 537ms/step - loss: 0.0795 - rpn_class_loss: 7.8503e-04 - rpn_bbox_loss: 0.0205 - mrcnn_class_loss: 0.0040 - mrcnn_bbox_loss: 0.0193 - mrcnn_mask_loss: 0.0349 - val_loss: 1.5137 - val_rpn_class_loss: 0.0043 - val_rpn_bbox_loss: 0.6431 - val_mrcnn_class_loss: 0.0053 - val_mrcnn_bbox_loss: 0.5667 - val_mrcnn_mask_loss: 0.2942
# Epoch 16/30
# 100/100 [==============================] - 54s 538ms/step - loss: 0.0498 - rpn_class_loss: 7.2197e-04 - rpn_bbox_loss: 0.0069 - mrcnn_class_loss: 0.0032 - mrcnn_bbox_loss: 0.0095 - mrcnn_mask_loss: 0.0294 - val_loss: 1.5836 - val_rpn_class_loss: 0.0034 - val_rpn_bbox_loss: 0.5999 - val_mrcnn_class_loss: 0.0065 - val_mrcnn_bbox_loss: 0.5958 - val_mrcnn_mask_loss: 0.3779
# Epoch 17/30
# 100/100 [==============================] - 54s 537ms/step - loss: 0.0393 - rpn_class_loss: 7.6141e-04 - rpn_bbox_loss: 0.0021 - mrcnn_class_loss: 0.0028 - mrcnn_bbox_loss: 0.0048 - mrcnn_mask_loss: 0.0287 - val_loss: 1.6029 - val_rpn_class_loss: 0.0037 - val_rpn_bbox_loss: 0.5926 - val_mrcnn_class_loss: 0.0083 - val_mrcnn_bbox_loss: 0.6430 - val_mrcnn_mask_loss: 0.3551
# Epoch 18/30
# 100/100 [==============================] - 54s 538ms/step - loss: 0.0423 - rpn_class_loss: 4.7812e-04 - rpn_bbox_loss: 0.0028 - mrcnn_class_loss: 0.0034 - mrcnn_bbox_loss: 0.0065 - mrcnn_mask_loss: 0.0290 - val_loss: 1.6647 - val_rpn_class_loss: 0.0037 - val_rpn_bbox_loss: 0.5752 - val_mrcnn_class_loss: 0.0109 - val_mrcnn_bbox_loss: 0.6857 - val_mrcnn_mask_loss: 0.3892
# Epoch 19/30
# 100/100 [==============================] - 54s 535ms/step - loss: 0.0417 - rpn_class_loss: 5.7469e-04 - rpn_bbox_loss: 0.0030 - mrcnn_class_loss: 0.0025 - mrcnn_bbox_loss: 0.0075 - mrcnn_mask_loss: 0.0282 - val_loss: 1.4645 - val_rpn_class_loss: 0.0037 - val_rpn_bbox_loss: 0.5733 - val_mrcnn_class_loss: 0.0089 - val_mrcnn_bbox_loss: 0.5925 - val_mrcnn_mask_loss: 0.2861
# Epoch 20/30
# 100/100 [==============================] - 54s 536ms/step - loss: 0.0388 - rpn_class_loss: 5.3275e-04 - rpn_bbox_loss: 0.0025 - mrcnn_class_loss: 0.0022 - mrcnn_bbox_loss: 0.0048 - mrcnn_mask_loss: 0.0287 - val_loss: 1.5885 - val_rpn_class_loss: 0.0032 - val_rpn_bbox_loss: 0.6037 - val_mrcnn_class_loss: 0.0064 - val_mrcnn_bbox_loss: 0.6930 - val_mrcnn_mask_loss: 0.2822
# Epoch 21/30
# 100/100 [==============================] - 54s 539ms/step - loss: 0.0353 - rpn_class_loss: 3.3219e-04 - rpn_bbox_loss: 0.0025 - mrcnn_class_loss: 0.0020 - mrcnn_bbox_loss: 0.0035 - mrcnn_mask_loss: 0.0270 - val_loss: 1.5409 - val_rpn_class_loss: 0.0042 - val_rpn_bbox_loss: 0.5802 - val_mrcnn_class_loss: 0.0110 - val_mrcnn_bbox_loss: 0.6535 - val_mrcnn_mask_loss: 0.2920
# Epoch 22/30
# 100/100 [==============================] - 55s 546ms/step - loss: 0.0293 - rpn_class_loss: 3.5502e-04 - rpn_bbox_loss: 0.0013 - mrcnn_class_loss: 0.0017 - mrcnn_bbox_loss: 0.0019 - mrcnn_mask_loss: 0.0241 - val_loss: 1.6845 - val_rpn_class_loss: 0.0028 - val_rpn_bbox_loss: 0.5863 - val_mrcnn_class_loss: 0.0126 - val_mrcnn_bbox_loss: 0.7101 - val_mrcnn_mask_loss: 0.3727
# Epoch 23/30
# 100/100 [==============================] - 54s 537ms/step - loss: 0.0315 - rpn_class_loss: 3.3321e-04 - rpn_bbox_loss: 0.0015 - mrcnn_class_loss: 0.0020 - mrcnn_bbox_loss: 0.0030 - mrcnn_mask_loss: 0.0247 - val_loss: 1.7014 - val_rpn_class_loss: 0.0029 - val_rpn_bbox_loss: 0.6016 - val_mrcnn_class_loss: 0.0096 - val_mrcnn_bbox_loss: 0.7165 - val_mrcnn_mask_loss: 0.3707
# Epoch 24/30
# 100/100 [==============================] - 53s 535ms/step - loss: 0.0302 - rpn_class_loss: 3.4756e-04 - rpn_bbox_loss: 0.0011 - mrcnn_class_loss: 0.0021 - mrcnn_bbox_loss: 0.0024 - mrcnn_mask_loss: 0.0243 - val_loss: 1.5679 - val_rpn_class_loss: 0.0031 - val_rpn_bbox_loss: 0.5819 - val_mrcnn_class_loss: 0.0089 - val_mrcnn_bbox_loss: 0.6479 - val_mrcnn_mask_loss: 0.3261
# Epoch 25/30
# 100/100 [==============================] - 53s 533ms/step - loss: 0.0280 - rpn_class_loss: 6.6224e-04 - rpn_bbox_loss: 7.9016e-04 - mrcnn_class_loss: 0.0017 - mrcnn_bbox_loss: 0.0012 - mrcnn_mask_loss: 0.0236 - val_loss: 1.6976 - val_rpn_class_loss: 0.0032 - val_rpn_bbox_loss: 0.5945 - val_mrcnn_class_loss: 0.0084 - val_mrcnn_bbox_loss: 0.7089 - val_mrcnn_mask_loss: 0.3825
# Epoch 26/30
# 100/100 [==============================] - 53s 535ms/step - loss: 0.0293 - rpn_class_loss: 2.3055e-04 - rpn_bbox_loss: 6.7042e-04 - mrcnn_class_loss: 0.0017 - mrcnn_bbox_loss: 0.0017 - mrcnn_mask_loss: 0.0251 - val_loss: 1.6664 - val_rpn_class_loss: 0.0031 - val_rpn_bbox_loss: 0.5973 - val_mrcnn_class_loss: 0.0099 - val_mrcnn_bbox_loss: 0.6862 - val_mrcnn_mask_loss: 0.3699
# Epoch 27/30
# 100/100 [==============================] - 54s 536ms/step - loss: 0.0284 - rpn_class_loss: 4.5900e-04 - rpn_bbox_loss: 0.0011 - mrcnn_class_loss: 0.0016 - mrcnn_bbox_loss: 0.0022 - mrcnn_mask_loss: 0.0231 - val_loss: 1.5758 - val_rpn_class_loss: 0.0035 - val_rpn_bbox_loss: 0.5634 - val_mrcnn_class_loss: 0.0081 - val_mrcnn_bbox_loss: 0.6351 - val_mrcnn_mask_loss: 0.3657
# Epoch 28/30
# 100/100 [==============================] - 54s 538ms/step - loss: 0.0268 - rpn_class_loss: 3.0928e-04 - rpn_bbox_loss: 9.5435e-04 - mrcnn_class_loss: 0.0015 - mrcnn_bbox_loss: 0.0016 - mrcnn_mask_loss: 0.0225 - val_loss: 1.5791 - val_rpn_class_loss: 0.0028 - val_rpn_bbox_loss: 0.5779 - val_mrcnn_class_loss: 0.0107 - val_mrcnn_bbox_loss: 0.6503 - val_mrcnn_mask_loss: 0.3375
# Epoch 29/30
# 100/100 [==============================] - 54s 535ms/step - loss: 0.0253 - rpn_class_loss: 4.0826e-04 - rpn_bbox_loss: 3.6145e-04 - mrcnn_class_loss: 0.0012 - mrcnn_bbox_loss: 0.0011 - mrcnn_mask_loss: 0.0223 - val_loss: 1.6573 - val_rpn_class_loss: 0.0030 - val_rpn_bbox_loss: 0.5676 - val_mrcnn_class_loss: 0.0137 - val_mrcnn_bbox_loss: 0.6776 - val_mrcnn_mask_loss: 0.3954
# Epoch 30/30
# 100/100 [==============================] - 54s 535ms/step - loss: 0.0296 - rpn_class_loss: 2.7307e-04 - rpn_bbox_loss: 6.1169e-04 - mrcnn_class_loss: 0.0016 - mrcnn_bbox_loss: 0.0016 - mrcnn_mask_loss: 0.0255 - val_loss: 1.5917 - val_rpn_class_loss: 0.0029 - val_rpn_bbox_loss: 0.5766 - val_mrcnn_class_loss: 0.0099 - val_mrcnn_bbox_loss: 0.6653 - val_mrcnn_mask_loss: 0.3369
